# %%
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import anndata as ad
import scanpy.external as sce
import decoupler as dc
import scanorama
import squidpy as sq
import numpy as np

# %%
adata=ad.read_h5ad("./results_harm.h5ad")

# %%
df=adata.obs[["anno_TM", "dataset"]]
df['dataset'].replace("926983", "P1", inplace=True)
df['dataset'].replace("926987", "P2", inplace=True)
df['dataset'].replace("926991", "P3", inplace=True)
df['dataset'].replace("926895", "P4", inplace=True)
df['dataset'].replace("38032", "P5", inplace=True)
df_grouped = df.groupby(['dataset', 'anno_TM']).size().reset_index(name='amount_of_anno_TM')
df_wide = df_grouped.pivot(index='dataset', columns='anno_TM', values='amount_of_anno_TM').fillna(0)
# Out:
# C:\Users\thmet\AppData\Local\Temp\ipykernel_7108\1272034629.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dataset'].replace("926983", "P1", inplace=True)
# C:\Users\thmet\AppData\Local\Temp\ipykernel_7108\1272034629.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dataset'].replace("926987", "P2", inplace=True)
# C:\Users\thmet\AppData\Local\Temp\ipykernel_7108\1272034629.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dataset'].replace("926991", "P3", inplace=True)
# C:\Users\thmet\AppData\Local\Temp\ipykernel_7108\1272034629.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dataset'].replace("926895", "P4", inplace=True)
# C:\Users\thmet\AppData\Local\Temp\ipykernel_7108\1272034629.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dataset'].replace("38032", "P5", inplace=True)

# %%
fig, ax = plt.subplots(1,1)
df_wide.plot(kind="bar",  
             stacked=True, 
             ax=ax, 
             edgecolor='black', 
             linewidth=0.5, 
             xlabel="",
             ylabel="number of spots", #"relative number of spots in %",
             grid=False, 
             color=([0.12156863, 0.46666667, 0.70588235, 1.        ],[1.         ,0.49803922 ,0.05490196 ,1.        ],[0.17254902, 0.62745098, 0.17254902, 1.        ],[0.83921569, 0.15294118, 0.15686275, 1.        ],[0.58039216, 0.40392157, 0.74117647, 1.        ],[0.54901961, 0.3372549 , 0.29411765, 1.        ] ,[0.89019608 ,0.46666667 ,0.76078431 ,1.        ],[0.7372549  ,0.74117647, 0.13333333 ,1.        ],[0.09019608, 0.74509804, 0.81176471, 1.        ],[0.68235294, 0.78039216, 0.90980392, 1.        ] ,[1.         ,0.73333333, 0.47058824 ,1.        ] ,[0.59607843, 0.8745098,  0.54117647, 1.        ], [1.        , 0.59607843, 0.58823529 ,1.        ],[0.77254902, 0.69019608, 0.83529412 ,1.        ] ,[0.76862745, 0.61176471, 0.58039216 ,1.        ],[0.96862745 ,0.71372549 ,0.82352941, 1.        ],[0.78039216 ,0.78039216 ,0.78039216 ,1.        ] ,[0.85882353, 0.85882353, 0.55294118, 1.        ], [0.61960784, 0.85490196 ,0.89803922 ,1.        ])
            )
ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.savefig("./plot_anno_absolute.pdf", bbox_inches="tight")
plt.savefig("./plot_anno_absolute.tiff", bbox_inches="tight")
plt.show()
